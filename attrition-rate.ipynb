# %% [markdown]
# <a href="https://www.kaggle.com/hamedetezadi/attrition-rate?scriptVersionId=89611917" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import datasets
from sklearn.metrics import accuracy_score

# %%
import os
# os.getcwd()

# %%
attrdata = pd.read_csv("../input/sampleattritiondataset/attrition-dataset.csv")

# %%
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 0         1  sid    9876544345  Mashhad         B2  Operation    Male    0.00
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
#
#   Tenure Grp.  Experience (YY.MM) Marital Status  Age in YY. Hiring Source  \
# 0        < =1                6.08         Single       27.12        Direct
# 1        < =1               13.00          Marr.       38.08        Direct
# 2        < =1               16.05          Marr.       36.04        Direct
# 3        < =1                6.06          Marr.       32.07        Direct
# 4        < =1                7.00          Marr.       32.05        Direct
#
#   Promoted/Non Promoted Job Role Match Stay/Left
# 0          Non Promoted            Yes      Left
# 1              Promoted             No      Stay
# 2              Promoted            Yes      Stay
# 3              Promoted            Yes      Stay
# 4          Non Promoted            Yes      Stay

# %%
attrdata.drop(0,inplace=True)

# %%
attrdata.isnull().sum()
# Out:
# table id                 0
# name                     0
# phone number             0
# Location                 0
# Emp. Group               0
# Function                 0
# Gender                   0
# Tenure                   0
# Tenure Grp.              0
# Experience (YY.MM)       4
# Marital Status           0
# Age in YY.               0
# Hiring Source            0
# Promoted/Non Promoted    0
# Job Role Match           2
# Stay/Left                0
# dtype: int64

# %%
attrdata.dropna(axis=0,inplace=True)

# %%
attrdata.isnull().sum()
# Out:
# table id                 0
# name                     0
# phone number             0
# Location                 0
# Emp. Group               0
# Function                 0
# Gender                   0
# Tenure                   0
# Tenure Grp.              0
# Experience (YY.MM)       0
# Marital Status           0
# Age in YY.               0
# Hiring Source            0
# Promoted/Non Promoted    0
# Job Role Match           0
# Stay/Left                0
# dtype: int64

# %%
attrdata.shape
# Out:
# (895, 16)

# %%
gender_dict = attrdata["Gender "].value_counts()
gender_dict
# Out:
# Male      655
# Female    234
# other       6
# Name: Gender , dtype: int64

# %%
promoted_dict = attrdata["Promoted/Non Promoted"].value_counts()
promoted_dict
# Out:
# Promoted        457
# Non Promoted    438
# Name: Promoted/Non Promoted, dtype: int64

# %%
func_dict = attrdata["Function"].value_counts()
func_dict
# Out:
# Operation    831
# Support       52
# Sales         12
# Name: Function, dtype: int64

# %%
Hiring_dict = attrdata["Hiring Source"].value_counts()
Hiring_dict
# Out:
# Direct               708
# Agency               116
# Employee Referral     71
# Name: Hiring Source, dtype: int64

# %%
Marital_dict = attrdata["Marital Status"].value_counts()
print(Marital_dict)
# Out:
# Single    533
# Marr.     356
# Div.        2
# NTBD        2
# Sep.        2
# Name: Marital Status, dtype: int64

# %%
Emp_dict = attrdata["Emp. Group"].value_counts()
Emp_dict['other group'] = 1
print(Emp_dict)
# Out:
# B1             537
# B2             275
# B3              59
# B0               8
# B4               7
# B5               4
# B7               2
# B6               1
# C3               1
# D2               1
# other group      1
# Name: Emp. Group, dtype: int64

# %%
job_dict = attrdata["Job Role Match"].value_counts()
job_dict
# Out:
# Yes    480
# No     415
# Name: Job Role Match, dtype: int64

# %%
tenure_dict = attrdata["Tenure Grp."].value_counts()
print(tenure_dict)
# Out:
# > 1 & < =3    626
# < =1          269
# Name: Tenure Grp., dtype: int64

# %%
# Build new dictionary to be used to categorize data column after
location_dict = attrdata["Location"].value_counts()
print(location_dict)

location_dict_new = {
    'Tehran':       7,
    'Orumieh':         6,
    'Karaj':     5,
    'Shiraz':     4,
    'Mashhad':          3,
    'Ahwaz':       2,
    'Maku':       1,
    'other place':         0,
}

print(location_dict_new)
# Out:
# Orumieh     255
# Karaj       236
# Tehran      210
# Shiraz       62
# Mashhad      55
# Ahwaz        29
# Maku         20
# Tabriz       14
# Taleghan      6
# Isfahan       4
# Gorgan        3
# Maragheh      1
# Name: Location, dtype: int64
# {'Tehran': 7, 'Orumieh': 6, 'Karaj': 5, 'Shiraz': 4, 'Mashhad': 3, 'Ahwaz': 2, 'Maku': 1, 'other place': 0}

# %%
def location(x):
    if str(x) in location_dict_new.keys():
        return location_dict_new[str(x)]
    else:
        return location_dict_new['other place']
    
data_l = attrdata["Location"].apply(location)
attrdata['New Location'] = data_l
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM) Marital Status  Age in YY. Hiring Source  \
# 1        < =1               13.00          Marr.       38.08        Direct
# 2        < =1               16.05          Marr.       36.04        Direct
# 3        < =1                6.06          Marr.       32.07        Direct
# 4        < =1                7.00          Marr.       32.05        Direct
# 5        < =1                9.01          Marr.       39.09        Direct
#
#   Promoted/Non Promoted Job Role Match Stay/Left  New Location
# 1              Promoted             No      Stay             5
# 2              Promoted            Yes      Stay             7
# 3              Promoted            Yes      Stay             5
# 4          Non Promoted            Yes      Stay             1
# 5              Promoted             No      Stay             7

# %%
gen = pd.get_dummies(attrdata["Function"])

# %%
hr = pd.get_dummies(attrdata["Hiring Source"])

# %%
# Marital Status
def Mar(x):
    if str(x) in Marital_dict.keys() and Marital_dict[str(x)] > 100:
        return str(x)
    else:
        return 'other status'
    
data_l = attrdata["Marital Status"].apply(Mar)
attrdata['New Marital'] = data_l
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM) Marital Status  Age in YY. Hiring Source  \
# 1        < =1               13.00          Marr.       38.08        Direct
# 2        < =1               16.05          Marr.       36.04        Direct
# 3        < =1                6.06          Marr.       32.07        Direct
# 4        < =1                7.00          Marr.       32.05        Direct
# 5        < =1                9.01          Marr.       39.09        Direct
#
#   Promoted/Non Promoted Job Role Match Stay/Left  New Location New Marital
# 1              Promoted             No      Stay             5       Marr.
# 2              Promoted            Yes      Stay             7       Marr.
# 3              Promoted            Yes      Stay             5       Marr.
# 4          Non Promoted            Yes      Stay             1       Marr.
# 5              Promoted             No      Stay             7       Marr.

# %%
Mr = pd.get_dummies(attrdata["New Marital"])

# %%
#Promoted/Not Promoted
def Promoted(x):
    if x == 'Promoted':
        return int(1)
    else:
        return int(0)
    
data_l = attrdata["Promoted/Non Promoted"].apply(Promoted)
attrdata['New Promotion'] = data_l
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM) Marital Status  Age in YY. Hiring Source  \
# 1        < =1               13.00          Marr.       38.08        Direct
# 2        < =1               16.05          Marr.       36.04        Direct
# 3        < =1                6.06          Marr.       32.07        Direct
# 4        < =1                7.00          Marr.       32.05        Direct
# 5        < =1                9.01          Marr.       39.09        Direct
#
#   Promoted/Non Promoted Job Role Match Stay/Left  New Location New Marital  \
# 1              Promoted             No      Stay             5       Marr.
# 2              Promoted            Yes      Stay             7       Marr.
# 3              Promoted            Yes      Stay             5       Marr.
# 4          Non Promoted            Yes      Stay             1       Marr.
# 5              Promoted             No      Stay             7       Marr.
#
#    New Promotion
# 1              1
# 2              1
# 3              1
# 4              0
# 5              1

# %%
# Employee Group
Emp_dict_new = {
    'B1': 4,
    'B2': 3,
    'B3': 2,
    'other group': 1,
}


def emp(x):
    if str(x) in Emp_dict_new.keys():
        return str(x)
    else:
        return 'other group'
    
data_l = attrdata["Emp. Group"].apply(emp)
attrdata['New EMP'] = data_l

emp = pd.get_dummies(attrdata["New EMP"])
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM) Marital Status  Age in YY. Hiring Source  \
# 1        < =1               13.00          Marr.       38.08        Direct
# 2        < =1               16.05          Marr.       36.04        Direct
# 3        < =1                6.06          Marr.       32.07        Direct
# 4        < =1                7.00          Marr.       32.05        Direct
# 5        < =1                9.01          Marr.       39.09        Direct
#
#   Promoted/Non Promoted Job Role Match Stay/Left  New Location New Marital  \
# 1              Promoted             No      Stay             5       Marr.
# 2              Promoted            Yes      Stay             7       Marr.
# 3              Promoted            Yes      Stay             5       Marr.
# 4          Non Promoted            Yes      Stay             1       Marr.
# 5              Promoted             No      Stay             7       Marr.
#
#    New Promotion      New EMP
# 1              1  other group
# 2              1           B3
# 3              1           B2
# 4              0           B2
# 5              1           B3

# %%
#Job Role Match
def Job(x):
    if x == 'Yes':
        return int(1)
    else:
        return int(0)
    
data_l = attrdata["Job Role Match"].apply(Job)
attrdata['New Job Role Match'] = data_l
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM)  ... Age in YY.  Hiring Source  \
# 1        < =1               13.00  ...      38.08         Direct
# 2        < =1               16.05  ...      36.04         Direct
# 3        < =1                6.06  ...      32.07         Direct
# 4        < =1                7.00  ...      32.05         Direct
# 5        < =1                9.01  ...      39.09         Direct
#
#   Promoted/Non Promoted Job Role Match Stay/Left New Location  New Marital  \
# 1              Promoted             No      Stay            5        Marr.
# 2              Promoted            Yes      Stay            7        Marr.
# 3              Promoted            Yes      Stay            5        Marr.
# 4          Non Promoted            Yes      Stay            1        Marr.
# 5              Promoted             No      Stay            7        Marr.
#
#   New Promotion      New EMP New Job Role Match
# 1             1  other group                  0
# 2             1           B3                  1
# 3             1           B2                  1
# 4             0           B2                  1
# 5             1           B3                  0
#
# [5 rows x 21 columns]

# %%
# Gender
def Gen(x):
    if x in gender_dict.keys():
        return str(x)
    else:
        return 'other'
    
data_l = attrdata["Gender "].apply(Gen)
attrdata['New Gender'] = data_l
attrdata.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM)  ... Hiring Source  Promoted/Non Promoted  \
# 1        < =1               13.00  ...        Direct               Promoted
# 2        < =1               16.05  ...        Direct               Promoted
# 3        < =1                6.06  ...        Direct               Promoted
# 4        < =1                7.00  ...        Direct           Non Promoted
# 5        < =1                9.01  ...        Direct               Promoted
#
#   Job Role Match Stay/Left New Location New Marital  New Promotion  \
# 1             No      Stay            5       Marr.              1
# 2            Yes      Stay            7       Marr.              1
# 3            Yes      Stay            5       Marr.              1
# 4            Yes      Stay            1       Marr.              0
# 5             No      Stay            7       Marr.              1
#
#        New EMP  New Job Role Match New Gender
# 1  other group                   0       Male
# 2           B3                   1       Male
# 3           B2                   1       Male
# 4           B2                   1       Male
# 5           B3                   0       Male
#
# [5 rows x 22 columns]

# %%
gend = pd.get_dummies(attrdata["New Gender"])

# %%
tengrp = pd.get_dummies(attrdata["Tenure Grp."])

# %%
dataset = pd.concat([attrdata, hr, Mr, emp, tengrp, gen, gend], axis = 1)

# %%
dataset.head()
# Out:
#    table id name  phone number Location Emp. Group   Function Gender   Tenure  \
# 1         2  sid    9876544345    Karaj         B7    Support    Male    0.00
# 2         3  sid    9876544345   Tehran         B3  Operation    Male    0.01
# 3         4  sid    9876544345    Karaj         B2  Operation    Male    0.01
# 4         5  sid    9876544345     Maku         B2  Operation    Male    0.00
# 5         6  sid    9876544345   Tehran         B3  Operation    Male    0.01
#
#   Tenure Grp.  Experience (YY.MM)  ... B3  other group < =1 > 1 & < =3  \
# 1        < =1               13.00  ...  0            1    1          0
# 2        < =1               16.05  ...  1            0    1          0
# 3        < =1                6.06  ...  0            0    1          0
# 4        < =1                7.00  ...  0            0    1          0
# 5        < =1                9.01  ...  1            0    1          0
#
#   Operation Sales  Support Female  Male other
# 1         0     0        1      0     1     0
# 2         1     0        0      0     1     0
# 3         1     0        0      0     1     0
# 4         1     0        0      0     1     0
# 5         1     0        0      0     1     0
#
# [5 rows x 40 columns]

# %%
dataset.columns
# Out:
# Index(['table id', 'name', 'phone number', 'Location', 'Emp. Group',
#        'Function', 'Gender ', 'Tenure', 'Tenure Grp.', 'Experience (YY.MM)',
#        'Marital Status', 'Age in YY.', 'Hiring Source',
#        'Promoted/Non Promoted', 'Job Role Match', 'Stay/Left', 'New Location',
#        'New Marital', 'New Promotion', 'New EMP', 'New Job Role Match',
#        'New Gender', 'Agency', 'Direct', 'Employee Referral', 'Marr.',
#        'Single', 'other status', 'B1', 'B2', 'B3', 'other group', '< =1',
#        '> 1 & < =3', 'Operation', 'Sales', 'Support', 'Female', 'Male',
#        'other'],
#       dtype='object')

# %%
dataset.drop(["table id", "name", "Marital Status","Promoted/Non Promoted","Function","Emp. Group","Job Role Match","Location"
              ,"Hiring Source","Gender ", 'Tenure', 'New Gender', 'New Marital', 'New EMP'],axis=1,inplace=True)

# %%
dataset1 = dataset.drop(['Tenure Grp.', 'phone number'], axis = 1)

# %%
dataset1.columns
# Out:
# Index(['Experience (YY.MM)', 'Age in YY.', 'Stay/Left', 'New Location',
#        'New Promotion', 'New Job Role Match', 'Agency', 'Direct',
#        'Employee Referral', 'Marr.', 'Single', 'other status', 'B1', 'B2',
#        'B3', 'other group', '< =1', '> 1 & < =3', 'Operation', 'Sales',
#        'Support', 'Female', 'Male', 'other'],
#       dtype='object')

# %%
# Target 
"""
def Target(x):
    if x in "Stay":
        return False
    else:
        return True
    
data_l = dataset1["Stay/Left"].apply(Target)
dataset1['Stay/Left'] = data_l
"""
dataset1['Stay/Left'].head()
# Out:
# 1    Stay
# 2    Stay
# 3    Stay
# 4    Stay
# 5    Stay
# Name: Stay/Left, dtype: object

# %%
dataset1.to_csv("processed table.csv")

# %%
dataset = pd.read_csv("processed table.csv")
dataset = pd.DataFrame(dataset)
y = dataset["Stay/Left"]
X = dataset.drop("Stay/Left",axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
X_train
# Out:
#      Unnamed: 0  Experience (YY.MM)  Age in YY.  New Location  New Promotion  \
# 684         688                4.09       26.06             7              0
# 220         224                2.08       26.00             5              0
# 476         480                7.11       29.06             2              1
# 431         435                3.00       25.02             5              1
# 868         872                7.00       28.06             7              1
# ..          ...                 ...         ...           ...            ...
# 360         364               15.04       37.02             7              1
# 709         713                3.02       27.09             6              0
# 439         443                7.06       34.06             7              0
# 174         178                3.10       28.00             6              1
# 122         125                4.10       28.09             7              1
#
#      New Job Role Match  Agency  Direct  Employee Referral  Marr.  ...  B3  \
# 684                   0       0       1                  0      0  ...   0
# 220                   0       1       0                  0      0  ...   0
# 476                   1       0       1                  0      0  ...   0
# 431                   0       0       1                  0      0  ...   0
# 868                   0       0       1                  0      1  ...   0
# ..                  ...     ...     ...                ...    ...  ...  ..
# 360                   0       0       1                  0      1  ...   1
# 709                   0       0       1                  0      0  ...   0
# 439                   1       1       0                  0      1  ...   0
# 174                   0       0       1                  0      1  ...   0
# 122                   0       0       1                  0      0  ...   0
#
#      other group  < =1  > 1 & < =3  Operation  Sales  Support  Female  Male  \
# 684            0     0           1          1      0        0       1     0
# 220            0     1           0          1      0        0       0     1
# 476            0     0           1          1      0        0       0     1
# 431            0     0           1          1      0        0       1     0
# 868            0     0           1          1      0        0       1     0
# ..           ...   ...         ...        ...    ...      ...     ...   ...
# 360            0     0           1          1      0        0       0     1
# 709            0     0           1          1      0        0       0     1
# 439            0     0           1          1      0        0       0     1
# 174            0     1           0          1      0        0       0     1
# 122            0     1           0          1      0        0       1     0
#
#      other
# 684      0
# 220      0
# 476      0
# 431      0
# 868      0
# ..     ...
# 360      0
# 709      0
# 439      0
# 174      0
# 122      0
#
# [716 rows x 24 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
lr=LogisticRegression(C = 0.1, random_state = 42, solver = 'liblinear')
dt=DecisionTreeClassifier()
rm=RandomForestClassifier()
gnb=GaussianNB()

# %%
for a,b in zip([lr,dt,rm,gnb],["Logistic Regression","Decision Tree","Random Forest","Naive Bayes"]):
    a.fit(X_train,y_train)
    prediction=a.predict(X_train)
    y_pred=a.predict(X_test)
    score1=accuracy_score(y_train,prediction)
    score=accuracy_score(y_test,y_pred)
    msg1="[%s] training data accuracy is : %f" % (b,score1)
    msg2="[%s] test data accuracy is : %f" % (b,score)
    print(msg1)
    print(msg2)
# Out:
# [Logistic Regression] training data accuracy is : 0.888268
# [Logistic Regression] test data accuracy is : 0.888268
# [Decision Tree] training data accuracy is : 1.000000
# [Decision Tree] test data accuracy is : 0.849162
# [Random Forest] training data accuracy is : 1.000000
# [Random Forest] test data accuracy is : 0.882682
# [Naive Bayes] training data accuracy is : 0.870112
# [Naive Bayes] test data accuracy is : 0.826816

# %% [markdown]
# Accuearcy 1 means **overfitting**, please comment how we can solve the overfitting **as a challenge**

# %%
model = lr.fit(X_train,y_train)

import pickle
# save the model to disk
filename = 'finalized_model.pickle'
pickle.dump(model, open(filename, 'wb'))
