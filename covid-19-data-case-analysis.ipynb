# %% [markdown]
# <a href="https://www.kaggle.com/hamedetezadi/covid-19-data-case-analysis?scriptVersionId=89462750" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %% [markdown]
# please check the below website for more dataset and information(comment more JSON link here in this notebook)
#
# **https://ourworldindata.org/coronavirus-source-data**

# %% [markdown]
# ### This above cell was last run on 12-01-2021, The dataset below is as of 12-01-2021.

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands       7     10024      9888
# 1     2                            Andhra Pradesh    1151   2318338   2302458
# 2     3                         Arunachal Pradesh      73     64466     64097
# 3     4                                     Assam    1436    724159    716084
# 4     5                                     Bihar     204    830245    817786
# 5     6                                Chandigarh      83     91795     90547
# 6     7                              Chhattisgarh     831   1151425   1136562
# 7     8  Dadra and Nagar Haveli and Daman and Diu       2     11440     11434
# 8     9                                     Delhi    1350   1861463   1833979
# 9    10                                       Goa     148    245109    241134
# 10   11                                   Gujarat     984   1223191   1211273
# 11   12                                   Haryana    1248    982862    971043
# 12   13                          Himachal Pradesh     537    283672    279013
# 13   14                         Jammu and Kashmir     380    453214    448085
# 14   15                                 Jharkhand     248    434536    428973
# 15   16                                 Karnataka    3324   3942346   3899034
# 16   17                                 Kerala***   16637   6510681   6427908
# 17   18                                    Ladakh     123     28112     27761
# 18   19                               Lakshadweep       1     11400     11347
# 19   20                            Madhya Pradesh    1559   1039899   1027607
# 20   21                               Maharashtra    8040   7868451   7716674
# 21   22                                   Manipur     268    136888    134506
# 22   23                                 Meghalaya     147     93582     91852
# 23   24                                   Mizoram    4615    217606    212329
# 24   25                                  Nagaland      62     35419     34600
# 25   26                                    Odisha    1434   1285760   1275228
# 26   27                                Puducherry      44    165742    163736
# 27   28                                    Punjab     418    758412    740275
# 28   29                                 Rajasthan    2940   1281154   1268672
# 29   30                                    Sikkim      37     39087     38607
# 30   31                                Tamil Nadu    3131   3450817   3409674
# 31   32                                 Telangana    1939    789676    783626
# 32   33                                   Tripura      10    100869     99940
# 33   34                               Uttarakhand    1964    436376    426726
# 34   35                             Uttar Pradesh    2364   2068965   2043126
# 35   36                               West Bengal    1703   2015772   1992891
# 36   37                                             59442  42962953  42388475
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           7         10024       9888        129
# 1    14729        1063       2318417    2302625      14729
# 2      296          65         64466      64105        296
# 3     6639        1424        724161     716098       6639
# 4    12255         189        830273     817829      12255
# 5     1165          71         91803      90567       1165
# 6    14032         719       1151486    1136735      14032
# 7        4           2         11440      11434          4
# 8    26134        1261       1861712    1834317      26134
# 9     3827         142        245123     241154       3827
# 10   10934         914       1223262    1211413      10935
# 11   10571        1218        983018     971229      10571
# 12    4122         511        283693     279059       4123
# 13    4749         357        453245     448139       4749
# 14    5315         233        434552     429004       5315
# 15   39988        3286       3942575    3899298      39991
# 16   66151       14968       6512089    6430941      66180               15
# 17     228         119         28119      27772        228
# 18      52           0         11400      11348         52
# 19   10733        1315       1040055    1028007      10733
# 20  143737        7711       7868813    7717362     143740
# 21    2114         248        136898     134535       2115
# 22    1583         143         93597      91869       1585
# 23     662        4524        217834     212647        663
# 24     757          58         35420      34605        757
# 25    9098        1246       1285889    1275542       9101
# 26    1962          39        165745     163744       1962
# 27   17719         383        758453     740350      17720
# 28    9542        2751       1281327    1269033       9543
# 29     443          38         39090      38609        443
# 30   38012        2770       3451013    3410228      38015
# 31    4111        1710        789758     783937       4111
# 32     919          10        100869      99940        919
# 33    7686         837        436708     428185       7686
# 34   23475        2133       2069126    2043518      23475
# 35   21178        1653       2015862    1993029      21180
# 36  515036       54118      42967315   42398095     515102               15
#
#    total state_code
# 0                35
# 1                28
# 2                12
# 3                18
# 4                10
# 5                04
# 6                22
# 7                26
# 8                07
# 9                30
# 10     1         24
# 11               06
# 12     1         02
# 13               01
# 14               20
# 15     3         29
# 16    44         32
# 17               37
# 18               31
# 19               23
# 20     3         27
# 21     1         14
# 22     2         17
# 23     1         15
# 24               13
# 25     3         21
# 26               34
# 27     1         03
# 28     1         08
# 29               11
# 30     3         33
# 31               36
# 32               16
# 33               05
# 34               09
# 35     2         19
# 36    66

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 13)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     object
# dtypes: int64(9), object(4)
# memory usage: 3.9+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno        active      positive         cured          death  \
# count  37.000000     37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000   3213.081081  2.322322e+06  2.291269e+06   27840.189189
# std    10.824355   9963.086928  7.084086e+06  6.988492e+06   86275.118123
# min     1.000000      1.000000  1.002400e+04  9.888000e+03       4.000000
# 25%    10.000000    123.000000  1.008690e+05  9.994000e+04    1165.000000
# 50%    19.000000    831.000000  7.241590e+05  7.160840e+05    6639.000000
# 75%    28.000000   1939.000000  1.285760e+06  1.275228e+06   14729.000000
# max    37.000000  59442.000000  4.296295e+07  4.238848e+07  515036.000000
#
#          new_active  new_positive     new_cured      new_death
# count     37.000000  3.700000e+01  3.700000e+01      37.000000
# mean    2925.297297  2.322558e+06  2.291789e+06   27843.351351
# std     9074.798458  7.084804e+06  6.990068e+06   86285.883724
# min        0.000000  1.002400e+04  9.888000e+03       4.000000
# 25%      119.000000  1.008690e+05  9.994000e+04    1165.000000
# 50%      719.000000  7.241610e+05  7.160980e+05    6639.000000
# 75%     1653.000000  1.285889e+06  1.275542e+06   14729.000000
# max    54118.000000  4.296732e+07  4.239810e+07  515102.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              37
# positive            37
# cured               37
# death               37
# new_active          37
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                6
# state_code          37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura      10    100869     99940     919          10
# 33   34    Uttarakhand    1964    436376    426726    7686         837
# 34   35  Uttar Pradesh    2364   2068965   2043126   23475        2133
# 35   36    West Bengal    1703   2015772   1992891   21178        1653
# 36   37                  59442  42962953  42388475  515036       54118
#
#     new_positive  new_cured  new_death death_reconsille total state_code
# 32        100869      99940        919                                16
# 33        436708     428185       7686                                05
# 34       2069126    2043518      23475                                09
# 35       2015862    1993029      21180                      2         19
# 36      42967315   42398095     515102               15    66

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands       7     10024     9888
# 1     2                            Andhra Pradesh    1151   2318338  2302458
# 2     3                         Arunachal Pradesh      73     64466    64097
# 3     4                                     Assam    1436    724159   716084
# 4     5                                     Bihar     204    830245   817786
# 5     6                                Chandigarh      83     91795    90547
# 6     7                              Chhattisgarh     831   1151425  1136562
# 7     8  Dadra and Nagar Haveli and Daman and Diu       2     11440    11434
# 8     9                                     Delhi    1350   1861463  1833979
# 9    10                                       Goa     148    245109   241134
# 10   11                                   Gujarat     984   1223191  1211273
# 11   12                                   Haryana    1248    982862   971043
# 12   13                          Himachal Pradesh     537    283672   279013
# 13   14                         Jammu and Kashmir     380    453214   448085
# 14   15                                 Jharkhand     248    434536   428973
# 15   16                                 Karnataka    3324   3942346  3899034
# 16   17                                 Kerala***   16637   6510681  6427908
# 17   18                                    Ladakh     123     28112    27761
# 18   19                               Lakshadweep       1     11400    11347
# 19   20                            Madhya Pradesh    1559   1039899  1027607
# 20   21                               Maharashtra    8040   7868451  7716674
# 21   22                                   Manipur     268    136888   134506
# 22   23                                 Meghalaya     147     93582    91852
# 23   24                                   Mizoram    4615    217606   212329
# 24   25                                  Nagaland      62     35419    34600
# 25   26                                    Odisha    1434   1285760  1275228
# 26   27                                Puducherry      44    165742   163736
# 27   28                                    Punjab     418    758412   740275
# 28   29                                 Rajasthan    2940   1281154  1268672
# 29   30                                    Sikkim      37     39087    38607
# 30   31                                Tamil Nadu    3131   3450817  3409674
# 31   32                                 Telangana    1939    789676   783626
# 32   33                                   Tripura      10    100869    99940
# 33   34                               Uttarakhand    1964    436376   426726
# 34   35                             Uttar Pradesh    2364   2068965  2043126
# 35   36                               West Bengal    1703   2015772  1992891
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           7         10024       9888        129
# 1    14729        1063       2318417    2302625      14729
# 2      296          65         64466      64105        296
# 3     6639        1424        724161     716098       6639
# 4    12255         189        830273     817829      12255
# 5     1165          71         91803      90567       1165
# 6    14032         719       1151486    1136735      14032
# 7        4           2         11440      11434          4
# 8    26134        1261       1861712    1834317      26134
# 9     3827         142        245123     241154       3827
# 10   10934         914       1223262    1211413      10935
# 11   10571        1218        983018     971229      10571
# 12    4122         511        283693     279059       4123
# 13    4749         357        453245     448139       4749
# 14    5315         233        434552     429004       5315
# 15   39988        3286       3942575    3899298      39991
# 16   66151       14968       6512089    6430941      66180               15
# 17     228         119         28119      27772        228
# 18      52           0         11400      11348         52
# 19   10733        1315       1040055    1028007      10733
# 20  143737        7711       7868813    7717362     143740
# 21    2114         248        136898     134535       2115
# 22    1583         143         93597      91869       1585
# 23     662        4524        217834     212647        663
# 24     757          58         35420      34605        757
# 25    9098        1246       1285889    1275542       9101
# 26    1962          39        165745     163744       1962
# 27   17719         383        758453     740350      17720
# 28    9542        2751       1281327    1269033       9543
# 29     443          38         39090      38609        443
# 30   38012        2770       3451013    3410228      38015
# 31    4111        1710        789758     783937       4111
# 32     919          10        100869      99940        919
# 33    7686         837        436708     428185       7686
# 34   23475        2133       2069126    2043518      23475
# 35   21178        1653       2015862    1993029      21180
#
#    total state_code
# 0                35
# 1                28
# 2                12
# 3                18
# 4                10
# 5                04
# 6                22
# 7                26
# 8                07
# 9                30
# 10     1         24
# 11               06
# 12     1         02
# 13               01
# 14               20
# 15     3         29
# 16    44         32
# 17               37
# 18               31
# 19               23
# 20     3         27
# 21     1         14
# 22     2         17
# 23     1         15
# 24               13
# 25     3         21
# 26               34
# 27     1         03
# 28     1         08
# 29               11
# 30     3         33
# 31               36
# 32               16
# 33               05
# 34               09
# 35     2         19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 59442

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 42962953

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 42388475

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 515051

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 54118

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 42967315

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 42398095

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 515102

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                           666
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                      59442
# positive                                                 42962953
# cured                                                    42388475
# death                                                      515051
# new_active                                                  54118
# new_positive                                             42967315
# new_cured                                                42398095
# new_death                                                  515102
# total                                              11344312131132
# state_code      3528121810042226073024060201202932373123271417...
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active                   59442
# positive              42962953
# cured                 42388475
# death                   515051
# new_active               54118
# new_positive          42967315
# new_cured             42398095
# new_death               515102
# total           11344312131132
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       7     10024     9888    129           7
# 1               Andhra Pradesh    1151   2318338  2302458  14729        1063
# 2            Arunachal Pradesh      73     64466    64097    296          65
# 3                        Assam    1436    724159   716084   6639        1424
# 4                        Bihar     204    830245   817786  12255         189
#
#    new_positive  new_cured  new_death death_reconsille total
# 0         10024       9888        129
# 1       2318417    2302625      14729
# 2         64466      64105        296
# 3        724161     716098       6639
# 4        830273     817829      12255

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       7     10024     9888    129           7
# Andhra Pradesh                 1151   2318338  2302458  14729        1063
# Arunachal Pradesh                73     64466    64097    296          65
# Assam                          1436    724159   716084   6639        1424
# Bihar                           204    830245   817786  12255         189
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10024       9888        129
# Andhra Pradesh                    2318417    2302625      14729
# Arunachal Pradesh                   64466      64105        296
# Assam                              724161     716098       6639
# Bihar                              830273     817829      12255
#
#                             death_reconsille total
# state_name
# Andaman and Nicobar Islands
# Andhra Pradesh
# Arunachal Pradesh
# Assam
# Bihar

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <AxesSubplot:ylabel='state_name'>
